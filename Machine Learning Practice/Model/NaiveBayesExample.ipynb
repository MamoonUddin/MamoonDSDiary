# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 15, 5
sns.set_style('darkgrid')

# %%
DiabetesData = pd.read_csv('diabetes.csv')
DiabetesData.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
DiabetesData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
DiabetesData.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
DiabetesData_Copy = DiabetesData.copy(deep = True)
DiabetesData_Copy["Glucose"] = DiabetesData_Copy["Glucose"].replace(0,np.NaN)
DiabetesData_Copy["BloodPressure"] = DiabetesData_Copy["BloodPressure"].replace(0,np.NaN)
DiabetesData_Copy["SkinThickness"] = DiabetesData_Copy["SkinThickness"].replace(0,np.NaN)
DiabetesData_Copy["Insulin"] = DiabetesData_Copy["Insulin"].replace(0,np.NaN)
DiabetesData_Copy["BMI"] = DiabetesData_Copy["BMI"].replace(0,np.NaN)

# %%
DiabetesData_Copy[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']].hist(figsize = (20,10))
plt.show()

# %%
DiabetesData_Copy["Glucose"].fillna(DiabetesData_Copy["Glucose"].mean(), inplace = True)
DiabetesData_Copy["BloodPressure"].fillna(DiabetesData_Copy["BloodPressure"].mean(), inplace = True)
DiabetesData_Copy["SkinThickness"].fillna(DiabetesData_Copy["SkinThickness"].mean(), inplace = True)
DiabetesData_Copy["Insulin"].fillna(DiabetesData_Copy["Insulin"].mean(), inplace = True)
DiabetesData_Copy["BMI"].fillna(DiabetesData_Copy["BMI"].mean(), inplace = True)

# %%
DiabetesData_Copy[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']].hist(figsize = (20,10))
plt.show()

# %%
sns.heatmap(DiabetesData_Copy.corr(), annot = True)
plt.title("THIS IS A CORRELATION MATRIX")
plt.show()

# %%
TestDiabetesData_Copy = DiabetesData.copy(deep = True)
TestDiabetesData_Copy["Glucose"] = TestDiabetesData_Copy["Glucose"].replace(0,np.NaN)
TestDiabetesData_Copy["BloodPressure"] = TestDiabetesData_Copy["BloodPressure"].replace(0,np.NaN)
TestDiabetesData_Copy["SkinThickness"] = TestDiabetesData_Copy["SkinThickness"].replace(0,np.NaN)
TestDiabetesData_Copy["Insulin"] = TestDiabetesData_Copy["Insulin"].replace(0,np.NaN)
TestDiabetesData_Copy["BMI"] = TestDiabetesData_Copy["BMI"].replace(0,np.NaN)
TestDiabetesData_Copy["Glucose"].dropna()
TestDiabetesData_Copy["BloodPressure"].dropna()
TestDiabetesData_Copy["SkinThickness"].dropna()
TestDiabetesData_Copy["Insulin"].dropna()
TestDiabetesData_Copy["BMI"].dropna()
TestDiabetesData_Copy[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']].hist(figsize = (20,10))
plt.show()

# %%
sns.heatmap(TestDiabetesData_Copy.corr(), annot = True)
plt.title("THIS IS A CORRELATION MATRIX BY REMOVING THE 0 DATA COMPLETELY")
plt.show()

# %%
TestDiabetesData_Copy.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  763.000000     733.000000     541.000000  394.000000
# mean      3.845052  121.686763      72.405184      29.153420  155.548223
# std       3.369578   30.535641      12.382158      10.476982  118.775855
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.000000      64.000000      22.000000   76.250000
# 50%       3.000000  117.000000      72.000000      29.000000  125.000000
# 75%       6.000000  141.000000      80.000000      36.000000  190.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  757.000000                768.000000  768.000000  768.000000
# mean    32.457464                  0.471876   33.240885    0.348958
# std      6.924988                  0.331329   11.760232    0.476951
# ...

# %%
TestDiabetesData_Copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   763 non-null    float64
#  2   BloodPressure             733 non-null    float64
#  3   SkinThickness             541 non-null    float64
#  4   Insulin                   394 non-null    float64
#  5   BMI                       757 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(6), int64(3)
# memory usage: 54.1 KB

# %%
## Removing the data seems to be an Horrible data cause now i only working with half ish data

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
# alpha parameter adjusts the point transparency. points with much more overlap will appear darker.
sns.scatterplot(x='BloodPressure', y='BMI', data=DiabetesData_Copy, alpha=0.3, ax=axes[0])
axes[0].set_title('BloodPressure VS. BMI')
sns.scatterplot(x='Glucose', y='DiabetesPedigreeFunction', data=DiabetesData_Copy, alpha=0.3, ax=axes[1])
axes[1].set_title('Glucose VS. DPF')
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
# alpha parameter adjusts the point transparency. points with much more overlap will appear darker.
sns.scatterplot(x='BloodPressure', y='BMI', data=TestDiabetesData_Copy, alpha=0.3, ax=axes[0])
axes[0].set_title('BloodPressure VS. BMI')
sns.scatterplot(x='Glucose', y='DiabetesPedigreeFunction', data=TestDiabetesData_Copy, alpha=0.3, ax=axes[1])
axes[1].set_title('Glucose VS. DPF')
plt.show()

# %%
import statsmodels.api as sm
import scipy
import pylab
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
sns.histplot(DiabetesData_Copy['Glucose'], ax=axes[0])
axes[0].set_title('Glucose Distribution')
sm.qqplot(DiabetesData_Copy['Glucose'], line='s', ax=axes[1])
axes[1].set_title('Glucose Q Q Plot')
pylab.show()
w, p_val = scipy.stats.shapiro(DiabetesData_Copy['Glucose'])
print('Shapiro Wilk: \nw:{}, p value:{}\n'.format(w,p_val))
d, p_val = scipy.stats.kstest(DiabetesData_Copy['Glucose'], 'norm')
print('Kolmogorov Smirnov: \nd:{}, p value:{}\n'.format(w,p_val))
print('Skewness of the data: \n{}\n'.format(scipy.stats.skew(DiabetesData_Copy['Glucose'])))
# Out:
# C:\Users\Mamoon College\anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# Shapiro Wilk:
# w:0.969902515411377, p value:1.7774986343921384e-11
#
# Kolmogorov Smirnov:
# d:0.969902515411377, p value:0.0
#
# Skewness of the data:
# 0.531677628850459

# %%
class_zero = DiabetesData_Copy[(DiabetesData_Copy['Outcome'] == 0)]
class_one = DiabetesData_Copy[(DiabetesData_Copy['Outcome'] == 1)]
plt.hist(x=class_zero['Glucose'], label='class 0', alpha=0.5)
plt.hist(x=class_one['Glucose'], label='class 1', alpha=0.5)
plt.legend()
plt.title('Glucose
Distribution')
plt.show()
# Out:
# C:\Users\Mamoon College\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 8233 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Mamoon College\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 8233 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
from sklearn.preprocessing import StandardScaler
#all columns except 'Outcome'
X = DiabetesData_Copy.drop('Outcome', axis=1)
y = DiabetesData_Copy['Outcome']
# create our scaler object
scaler = StandardScaler()
# use our scaler object to transform/scale our data and save it into X_scaled
X_scaled = scaler.fit_transform(X)
# reassign X to a new DataFrame using the X_scaled values.
X = pd.DataFrame(data=X_scaled, columns=X.columns)

# %%
X.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness       Insulin  \
# 0     0.639947  0.865108      -0.033518   6.655021e-01 -3.345079e-16
# 1    -0.844885 -1.206162      -0.529859  -1.746338e-02 -3.345079e-16
# 2     1.233880  2.015813      -0.695306   8.087936e-16 -3.345079e-16
# 3    -0.844885 -1.074652      -0.529859  -7.004289e-01 -7.243887e-01
# 4    -1.141852  0.503458      -2.680669   6.655021e-01  1.465506e-01
#
#         BMI  DiabetesPedigreeFunction       Age
# 0  0.166292                  0.468492  1.425995
# 1 -0.852531                 -0.365061 -0.190672
# 2 -1.332833                  0.604397 -0.105584
# 3 -0.634212                 -0.920763 -1.041549
# 4  1.548980                  5.484909 -0.020496

# %%
sns.countplot(x=DiabetesData_Copy['Outcome'])
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
# will append scores here for plotting later
test_scores = []
train_scores = []
# testing k values from 1-14
for i in range(1,15):
#create a model with k=i
    knn = KNeighborsClassifier(i)
# train the model
    knn.fit(X_train,y_train)
# append scores.
    train_scores.append(knn.score(X_train,y_train))
    test_scores.append(knn.score(X_test,y_test))

# %%
sns.lineplot(x=range(1,15), y=train_scores, marker='*', label='Train Score')
sns.lineplot(x=range(1,15), y=test_scores, marker='o', label='Test Score')
plt.title('K vs. Score')
plt.xlabel('K')
plt.ylabel('Score')
plt.show()

# %%
knn = KNeighborsClassifier(11)
knn.fit(X_train,y_train)
knn.score(X_test,y_test)
# Out:
# 0.7489177489177489

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
y_pred = knn.predict(X_test)
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.86      0.82       150
#            1       0.68      0.54      0.60        81
#
#     accuracy                           0.75       231
#    macro avg       0.73      0.70      0.71       231
# weighted avg       0.74      0.75      0.74       231
#
# [[129  21]
#  [ 37  44]]

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
# alpha parameter adjusts the point transparency. points with much more overlap will appear darker.
sns.scatterplot(x='BloodPressure', y='BMI', data=TestDiabetesData_Copy, alpha=0.3, ax=axes[0])
axes[0].set_title('Test BloodPressure VS. BMI')
sns.scatterplot(x='Glucose', y='DiabetesPedigreeFunction', data=TestDiabetesData_Copy, alpha=0.3, ax=axes[1])
axes[1].set_title('Test Glucose VS. DPF')
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
sns.histplot(TestDiabetesData_Copy['Glucose'], ax=axes[0])
axes[0].set_title('Glucose Distribution')
sm.qqplot(TestDiabetesData_Copy['Glucose'], line='s', ax=axes[1])
axes[1].set_title('Glucose Q Q Plot')
pylab.show()
w, p_val = scipy.stats.shapiro(TestDiabetesData_Copy['Glucose'])
print('Shapiro Wilk: \nw:{}, p value:{}\n'.format(w,p_val))
d, p_val = scipy.stats.kstest(TestDiabetesData_Copy['Glucose'], 'norm')
print('Kolmogorov Smirnov: \nd:{}, p value:{}\n'.format(w,p_val))
print('Skewness of the data: \n{}\n'.format(scipy.stats.skew(TestDiabetesData_Copy['Glucose'])))
# Out:
# C:\Users\Mamoon College\anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# Shapiro Wilk:
# w:nan, p value:1.0
#
# Kolmogorov Smirnov:
# d:nan, p value:nan
#
# Skewness of the data:
# nan

# %%
class_zero = TestDiabetesData_Copy[(TestDiabetesData_Copy['Outcome'] == 0)]
class_one = TestDiabetesData_Copy[(TestDiabetesData_Copy['Outcome'] == 1)]
plt.hist(x=class_zero['Glucose'], label='class 0', alpha=0.5)
plt.hist(x=class_one['Glucose'], label='class 1', alpha=0.5)
plt.legend()
plt.title('Glucose Distribution')
plt.show()

# %%
X = TestDiabetesData_Copy.drop('Outcome', axis=1)
y = TestDiabetesData_Copy['Outcome']
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X = pd.DataFrame(data=X_scaled, columns=X.columns)

# %%
sns.lineplot(x=range(1,15), y=train_scores, marker='*', label='Train Score')
sns.lineplot(x=range(1,15), y=test_scores, marker='o', label='Test Score')
plt.title('K vs. Score')
plt.xlabel('K')
plt.ylabel('Score')
plt.show()

# %%
knn = KNeighborsClassifier(11)
knn.fit(X_train,y_train)
knn.score(X_test,y_test)
# Out:
# 0.7489177489177489

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
y_pred = knn.predict(X_test)
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.86      0.82       150
#            1       0.68      0.54      0.60        81
#
#     accuracy                           0.75       231
#    macro avg       0.73      0.70      0.71       231
# weighted avg       0.74      0.75      0.74       231
#
# [[129  21]
#  [ 37  44]]

# %%
# Part 2 of lab 7

# %%
adult_df = pd.read_csv('adult.csv', header=None)
adult_df.columns = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation',
'relationship','race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
'income']
adult_df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
categoricals = ['workclass', 'education', 'marital_status', 'occupation', 'relationship', 'race', 'sex',
'native_country', 'income']
numericals = ['age', 'fnlwgt', 'education_num', 'capital_gain', 'capital_loss', 'hours_per_week']

# %%
sns.countplot(x=adult_df['income'], hue='sex', data=adult_df)
plt.show()

# %%
sns.countplot(x=adult_df['education'], order=adult_df['education'].value_counts().index)
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(x=adult_df['race'], data=adult_df)
plt.show()

# %%
sns.countplot(x=adult_df['occupation'], data=adult_df, order=adult_df['occupation'].value_counts().index)
plt.xticks(rotation=45)
plt.show()

# %%
adult_df['workclass'] = adult_df['workclass'].replace(' ?', np.NaN)
adult_df['occupation'] = adult_df['occupation'].replace(' ?', np.NaN)
adult_df['native_country'] = adult_df['native_country'].replace(' ?', np.NaN)

# %%
sns.barplot(x=adult_df.columns, y=adult_df.isnull().sum().values)
plt.xticks(rotation=45)
plt.show()

# %%
adult_df[numericals].head()
# Out:
#    age  fnlwgt  education_num  capital_gain  capital_loss  hours_per_week
# 0   39   77516             13          2174             0              40
# 1   50   83311             13             0             0              13
# 2   38  215646              9             0             0              40
# 3   53  234721              7             0             0              40
# 4   28  338409             13             0             0              40

# %%
for variable in numericals:
    if not adult_df[adult_df[variable] == ' ?'].empty:
        print(f'{variable} contains missing values ( ?)')

# %%
adult_df[numericals].hist(figsize=(20, 10))
plt.show()

# %%
adult_df['workclass'].fillna(adult_df['workclass'].mode()[0], inplace=True)
adult_df['occupation'].fillna(adult_df['occupation'].mode()[0], inplace=True)
adult_df['native_country'].fillna(adult_df['native_country'].mode()[0], inplace=True)

# %%
adult_df = pd.get_dummies(data=adult_df, columns=categoricals, drop_first=True)

# %%
adult_df.head()
# Out:
#    age  fnlwgt  education_num  capital_gain  capital_loss  hours_per_week  \
# 0   39   77516             13          2174             0              40
# 1   50   83311             13             0             0              13
# 2   38  215646              9             0             0              40
# 3   53  234721              7             0             0              40
# 4   28  338409             13             0             0              40
#
#    workclass_ Local-gov  workclass_ Never-worked  workclass_ Private  \
# 0                     0                        0                   0
# 1                     0                        0                   0
# 2                     0                        0                   1
# 3                     0                        0                   1
# 4                     0                        0                   1
#
#    workclass_ Self-emp-inc  ...  native_country_ Puerto-Rico  \
# ...

# %%
from sklearn.preprocessing import RobustScaler

X = adult_df.drop('income_ >50K', axis=1)
y = adult_df['income_ >50K']

scaler = RobustScaler()

X_scaled = scaler.fit_transform(X[numericals])

X[numericals] = X_scaled

# %%
X.head()
# Out:
#     age    fnlwgt  education_num  capital_gain  capital_loss  hours_per_week  \
# 0  0.10 -0.845803       1.000000        2174.0           0.0             0.0
# 1  0.65 -0.797197       1.000000           0.0           0.0            -5.4
# 2  0.05  0.312773      -0.333333           0.0           0.0             0.0
# 3  0.80  0.472766      -1.000000           0.0           0.0             0.0
# 4 -0.45  1.342456       1.000000           0.0           0.0             0.0
#
#    workclass_ Local-gov  workclass_ Never-worked  workclass_ Private  \
# 0                     0                        0                   0
# 1                     0                        0                   0
# 2                     0                        0                   1
# 3                     0                        0                   1
# 4                     0                        0                   1
#
#    workclass_ Self-emp-inc  ...  native_country_ Portugal  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()

gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(X_test)

# %%
y_pred_train = gnb.predict(X_train)
print('Training set score: {:.4f}'.format(gnb.score(X_train, y_train)))
print('Test set score: {:.4f}'.format(gnb.score(X_test, y_test)))
# Out:
# Training set score: 0.8245
# Test set score: 0.8236

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print('Confusion matrix\n\n', cm)
print('\nTrue Positives(TP) = ', cm[0,0])
print('\nTrue Negatives(TN) = ', cm[1,1])
print('\nFalse Positives(FP) = ', cm[0,1])
print('\nFalse Negatives(FN) = ', cm[1,0])
# Out:
# Confusion matrix
#
#  [[6289 1110]
#  [ 613 1757]]
#
# True Positives(TP) =  6289
#
# True Negatives(TN) =  1757
#
# False Positives(FP) =  1110
#
# False Negatives(FN) =  613

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88      7399
#            1       0.61      0.74      0.67      2370
#
#     accuracy                           0.82      9769
#    macro avg       0.76      0.80      0.78      9769
# weighted avg       0.84      0.82      0.83      9769

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(gnb, X_train, y_train, cv = 10, scoring='accuracy')
print('Cross validation scores:{}'.format(scores))

print('\nAverage cross validation score: {:.4f}'.format(scores.mean()))
# Out:
# Cross validation scores:[0.81315789 0.83289474 0.81834138 0.82360685 0.82799473 0.81834138
#  0.81526986 0.83369899 0.82843352 0.82492321]
#
# Average cross validation score: 0.8237

# %%
Testadult_df = pd.read_csv('adult.csv', header=None)
Testadult_df.head()
# Out:
#    0                  1       2           3   4                    5   \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7       8        9     10  11  12  \
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#                13      14
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...
